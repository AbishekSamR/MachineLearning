# %% [markdown]
# <a href="https://colab.research.google.com/github/AbishekSamR/MachineLearning/blob/main/Machine_Learning_Internship.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-97fc0607-49aa-4f05-adff-093cc8ce8cdc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-97fc0607-49aa-4f05-adff-093cc8ce8cdc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv(r'heart .csv')

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.shape
# Out:
# (303, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.fillna(method='ffill')
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df.fillna(method='bfill')
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df.fillna(method='ffill', inplace=True)

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-ec8beace-b7c5-42e0-9c65-d29275e25daf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ec8beace-b7c5-42e0-9c65-d29275e25daf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-b917dbc7-c2ec-4f2e-86c8-b46989d721cc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b917dbc7-c2ec-4f2e-86c8-b46989d721cc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv(r'heart(1).csv')

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    1
# chol        0
# fbs         0
# restecg     0
# thalach     2
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3     145.0   233    1        0    150.0      0      2.3
# 1     37    1   2     130.0   250    0        1    187.0      0      3.5
# 2     41    0   1     130.0   204    0        0    172.0      0      1.4
# 3     56    1   1     120.0   236    0        1    178.0      0      0.8
# 4     57    0   0       NaN   354    0        1    163.0      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0     140.0   241    0        1    123.0      1      0.2
# 299   45    1   3     110.0   264    0        1    132.0      0      1.2
# 300   68    1   0     144.0   193    1        1    141.0      0      3.4
# 301   57    1   0     130.0   131    0        1    115.0      1      1.2
# 302   57    0   1     130.0   236    0        0    174.0      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.shape
# Out:
# (300, 14)

# %%
 x=df[['age','sex','cp','fbs']]

# %%
x
# Out:
#      age  sex  cp  fbs
# 0     63    1   3    1
# 1     37    1   2    0
# 2     41    0   1    0
# 3     56    1   1    0
# 5     57    1   0    0
# ..   ...  ...  ..  ...
# 298   57    0   0    0
# 299   45    1   3    0
# 300   68    1   0    1
# 301   57    1   0    0
# 302   57    0   1    0
#
# [300 rows x 4 columns]

# %%
y=df[['target']]

# %%
y
# Out:
#      target
# 0         1
# 1         1
# 2         1
# 3         1
# 5         1
# ..      ...
# 298       0
# 299       0
# 300       0
# 301       0
# 302       0
#
# [300 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(x,y)
ypred=model.predict(xtest)
score=accuracy_score(ytest,ypred)

# %%
score
# Out:
# 0.8833333333333333

# %%
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(x,y)
ypred=model.predict(xtest)
score=accuracy_score(ytest,ypred)

# %%
score
# Out:
# 0.8833333333333333

# %%
prediction=model.predict([[63,1,3,145.0]])
print(prediction)
# Out:
# [1]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
prediction=model.predict([[57,0,0,140.0]])
print(prediction)
# Out:
# [0]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
prediction=model.predict([[0.0,1,1,2]])
print(prediction)
# Out:
# [1]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(ytest,ypred)
print(cm)
# Out:
# [[19  9]
#  [10 22]]

# %%
from sklearn.metrics import classification_report
cr=classification_report(ytest,ypred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.68      0.67        28
#            1       0.71      0.69      0.70        32
#
#     accuracy                           0.68        60
#    macro avg       0.68      0.68      0.68        60
# weighted avg       0.68      0.68      0.68        60

# %%
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

model=RandomForestClassifier()
model.fit(x,y)
ypred=model.predict(xtest)
score=accuracy_score(ytest,ypred)
print(score)
# Out:
# <ipython-input-57-06c004495ddf>:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(x,y)
# 0.9

# %%
prediction = model.predict([[63,1,3,145.0]])
print(prediction)
# Out:
# [1]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(ytest,ypred)
print(cm)
# Out:
# [[27  1]
#  [ 5 27]]

# %%
from sklearn.metrics import classification_report
cr=classification_report(ytest,ypred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.96      0.90        28
#            1       0.96      0.84      0.90        32
#
#     accuracy                           0.90        60
#    macro avg       0.90      0.90      0.90        60
# weighted avg       0.91      0.90      0.90        60

# %%
  from sklearn.metrics import accuracy_score
  from sklearn import svm

# %%
model=svm.SVC()
model.fit(xtrain,ytrain)
ypred=model.predict(xtest)
score=accuracy_score(ytest,ypred)
print(score)
# Out:
# 0.6666666666666666
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
clf=DecisionTreeClassifier()
clf.fit(xtrain,ytrain)
ypred=clf.predict(xtest)
score=accuracy_score(ytest,ypred)
print(score)
# Out:
# 0.6666666666666666
